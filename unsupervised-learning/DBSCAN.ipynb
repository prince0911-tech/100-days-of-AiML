# %%
from sklearn.datasets import load_iris
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
iris = load_iris()

X = iris.data
y  =iris.target

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# visualize
sns.scatterplot(x=X_scaled[:, 0], y=X_scaled[:,2])
# Out:
# <Axes: >

# %%
# DBSCAN

from sklearn.cluster import DBSCAN

dbscan = DBSCAN(
    eps = 0.8,
    min_samples = 5
)

# %%
labels = dbscan.fit_predict(X_scaled)

# %%
sns.scatterplot(x=X_scaled[:, 0], y=X_scaled[:,2], c=labels)
# Out:
# <Axes: >

# %% [markdown]
# labels

# %% [markdown]
# ### Non-linear data

# %%
from sklearn.datasets import make_moons

# %%
X, y = make_moons(
    n_samples=300,
    noise=0.05,
    random_state=42
)

# %%
X_scaled = scaler.fit_transform(X)

sns.scatterplot(x=X_scaled[:,0], y=X_scaled[:, 1])
# Out:
# <Axes: >

# %%
# K-Means
from sklearn.cluster import KMeans

kmeans = KMeans(
    n_clusters=2,
    random_state=42,
)

labels = kmeans.fit_predict(X_scaled)
# Out:
# C:\Users\princ\anaconda3\envs\apna_college\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
sns.scatterplot(x=X_scaled[:,0], y=X_scaled[:, 1], c=labels)
# Out:
# <Axes: >

# %%
# DBSCAN

dbscan = DBSCAN(
    eps=0.5,
    min_samples=5
)

labels = dbscan.fit_predict(X_scaled)

# %%
sns.scatterplot(x=X_scaled[:,0], y=X_scaled[:, 1], c=labels)
# Out:
# <Axes: >

# %% [markdown]
# ### anomaly detection

# %%
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons

# %%
X,y=make_moons(
    n_samples=500,
    noise=0.1,
    random_state=42
)

# %%
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
sns.scatterplot(x=X_scaled[:,0],y=X_scaled[:,1])
# Out:
# <Axes: >

# %%
dbscan=DBSCAN(
    eps=0.2,
    min_samples=4
)

labels=dbscan.fit_predict(X_scaled)

# %%
sns.scatterplot(x=X_scaled[:,0],y=X_scaled[:,1],c=labels)
# Out:
# <Axes: >
