# %%
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
import pandas as pd

# %%
iris = load_iris()

# %%
X = iris.data
y = iris.target

# %%
X.shape
# Out:
# (150, 4)

# %%
# Visualize
sns.scatterplot(x=X[:,0], y=X[:,2])
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# optional - dimensionality reduciton using PCA
from sklearn.decomposition import PCA

pca = PCA(n_components=2)

pca_data = pca.fit_transform(X_scaled)

# %%
sns.lineplot(x=range(1, 11), y=wcss, marker='o')
# Out:
# <Axes: >

# %%
# KMeans

kmeans = KMeans(n_clusters=3, random_state=10)
labels = kmeans.fit_predict(pca_data)

sns.scatterplot(x=pca_data[:, 0], y=pca_data[:,1], c=labels)
sns.scatterplot(x=kmeans.cluster_centers_[:, 0], y=kmeans.cluster_centers_[:, 1], marker="X", c="red", s=200)
# Out:
# C:\Users\princ\anaconda3\envs\apna_college\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# <Axes: >
